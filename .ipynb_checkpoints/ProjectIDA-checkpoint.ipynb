# %% [markdown]
# # Analysis of Spotify Top-2000 songs

# %% [markdown]
# ### Content:
# * 1.Introduction
# * 2.Description of project
# * 3.Research questions
# * 4.Data preparation:cleaning and shaping
# * 5.Data visualization

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# In the modern world, almost everyone interacts with an art form - music. Music is listened to, created, reproduced and sung. Over the years, listening to music has developed with tremendous success and today one of the most popular music services is the streaming service Spotify, with nearly 300 million users worldwide. The service contains a database of 60 million tracks of all genres. As users themselves say, this service, unlike other platforms, has many advantages, such as: a simple and convenient interface, reasonable rates for access to catalogs of various tracks, a high-quality algorithm for selecting individual playlists, easy registration and payment methods, integration with social networks, cross-platform, streaming of tracks and albums - this function affects the increase in the popularity of an artist all over the world (the more followers and the number of listens to the artist's tracks, the artist is recognizable).Those songs that achieve great success among the audience remain in memory for a long time. Their influence on people can be so great that they leave their contribution to history. Songs can sometimes show us the development of entire generations.So, main goal of the project is to research and see power of the music.

# %% [markdown]
# ## 2. Description of project

# %% [markdown]
# The popularity factor is central to this research.
# The analysis is based on ready dataset taken from site kaggle.com :
# (https://www.kaggle.com/iamsumat/spotify-top-2000s-mega-dataset).
# Given dataset contains audio statistics of the top 2000 tracks on Spotify. The data contains about 15 columns each describing the track and it's qualities.Chosen tracks were released in period from 1956 to 2019 and there were included songs from some notable and famous artists like Queen, The Beatles, Guns N' Roses, etc.
# This data is extracted from the Spotify playlist - Top 2000s on PlaylistMachinery(@plamere) using Selenium with Python. More specifically, it was scraped from http://sortyourmusic.playlistmachinery.com/ This data contains audio features like Danceability, BPM, Liveness, Valence(Positivity) and many more.
# Each feature's description has been given in detail below.
# * Index is ID.
# * Title- name of the track.
# * Artist- name of the artist.
# * Top Genre is the genre of track.
# * Year is the year that track was released.
# * Beats per Minute(BPM) - The tempo of the song.
# * Energy: The energy of a song - the higher the value, the more energtic song is.
# * Danceability - The higher the value, the easier to dance to this song.
# * Loudness - The higher the value, the louder the song is.
# * Liveness - The higher the value , the more lively song hears to listener.
# * Valence - The higher the value, the more positive mood for the song is.
# * Length - duration of the song.
# * Acoustic - The higher the value the more acoustic the song is.
# * Speechiness- The higher the value the more spoken words the song contains.
# * Popularity - The higher the value the more popular the song is.

# %% [markdown]
# ##  3.Formulation of research questions

# %% [markdown]
# #### For detailed and deep analysis, we need to answer to the following questions:
# 1. Analyze the most known Artists in the world of all times and each decade
# 2. Analyze the most listened genres of all times and each decade
# 3. Analyze the in which years people had listened dance and energetic songs
# 4. Find trend for acousticness in songs was popular in 1960s, than they are today
# 5. Find which words contained in songs are more popular?

# %% [markdown]
# ## 4.Data preparation: cleaning and shaping
# for well-working with data, we need to prepare it to right format.
# * find all the missing values.
# * renaming some columns
# * convert column length(duration) from object to int type
# * convert all the negative values in column 'loudness' to the positive
# * grouping data by columns

# %%
# importing useful packages
import numpy as np
import pandas as pd
import csv
import random
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# making data frame from csv file  and making the index from column "Index"
top = pd.read_csv(r"C:\Users\User\Desktop\data analytics\Project\Analysis-Spotify-Top-2000\Spotify-2000.csv",delimiter = ";",
             encoding = "utf - 8", doublequote=True, engine="python", index_col = "Index")
top.head(5)
# Out:
#                         Title             Artist            Top Genre  Year  \
# Index
# 1                     Sunrise        Norah Jones      adult standards  2004
# 2                 Black Night        Deep Purple           album rock  2000
# 3              Clint Eastwood           Gorillaz  alternative hip hop  2001
# 4               The Pretender       Foo Fighters    alternative metal  2007
# 5      Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
#
#        Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# Index
# 1                         157      30            53            -14        11
# 2                         135      79            50            -11        17
# 3                         168      69            66             -9         7
# 4                         173      96            43             -4         3
# 5                         106      82            58             -5        10
#
#        Valence Length (Duration)  Acousticness  Speechiness  Popularity
# Index
# 1           68               201            94            3          71
# 2           81               207            17            7          39
# 3           52               341             2           17          69
# 4           37               269             0            4          76
# 5           87               256             1            3          59

# %%
#show size of table- in rows and columns
top.shape
# Out:
# (1994, 14)

# %%
#showing all info about columns
top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 1 to 1994
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   1994 non-null   object
#  1   Artist                  1994 non-null   object
#  2   Top Genre               1994 non-null   object
#  3   Year                    1994 non-null   int64
#  4   Beats Per Minute (BPM)  1994 non-null   int64
#  5   Energy                  1994 non-null   int64
#  6   Danceability            1994 non-null   int64
#  7   Loudness (dB)           1994 non-null   int64
#  8   Liveness                1994 non-null   int64
#  9   Valence                 1994 non-null   int64
#  10  Length (Duration)       1994 non-null   object
#  11  Acousticness            1994 non-null   int64
#  12  Speechiness             1994 non-null   int64
#  13  Popularity              1994 non-null   int64
# dtypes: int64(10), object(4)
# memory usage: 233.7+ KB

# %%
#counting types of columns
top.dtypes.value_counts()
# Out:
# int64     11
# object     3
# dtype: int64

# %%
# get all the statistical derscription of numerical columns
top.describe()
# Out:
#               Year  Beats Per Minute (BPM)       Energy  Danceability  \
# count  1994.000000             1994.000000  1994.000000   1994.000000
# mean   1992.992979              120.215647    59.679539     53.238215
# std      16.116048               28.028096    22.154322     15.351507
# min    1956.000000               37.000000     3.000000     10.000000
# 25%    1979.000000               99.000000    42.000000     43.000000
# 50%    1993.000000              119.000000    61.000000     53.000000
# 75%    2007.000000              136.000000    78.000000     64.000000
# max    2019.000000              206.000000   100.000000     96.000000
#
#        Loudness (dB)     Liveness      Valence  Acousticness  Speechiness  \
# count    1994.000000  1994.000000  1994.000000   1994.000000  1994.000000
# mean       -9.008526    19.012036    49.408726     28.858074     4.994985
# std         3.647876    16.727378    24.858212     29.011986     4.401566
# min       -27.000000     2.000000     3.000000      0.000000     2.000000
# 25%       -11.000000     9.000000    29.000000      3.000000     3.000000
# 50%        -8.000000    12.000000    47.000000     18.000000     4.000000
# 75%        -6.000000    23.000000    69.750000     50.000000     5.000000
# max        -2.000000    99.000000    99.000000     99.000000    55.000000
#
#        Popularity
# count  1994.00000
# mean     59.52658
# std      14.35160
# min      11.00000
# 25%      49.25000
# 50%      62.00000
# 75%      71.00000
# max     100.00000

# %%
#finding missing values on each column
top.isnull().sum()
# Out:
# Title                     0
# Artist                    0
# Top Genre                 0
# Year                      0
# Beats Per Minute (BPM)    0
# Energy                    0
# Danceability              0
# Loudness (dB)             0
# Liveness                  0
# Valence                   0
# Length (Duration)         0
# Acousticness              0
# Speechiness               0
# Popularity                0
# dtype: int64

# %% [markdown]
# #### As we see, there are no missing values compared part 1 of submission
# This is because, initially, the dataset itself was incorrectly represented and damaged, and therefore I decided to format it, since creating a new dataframe with missing values and filtering them, and then joining two dataframes could not be possible due to the very damaged file with the dataset , and now that it has been formatted, all records are reflected correctly and without data missing. It was the only correct way to solve the problem,honestly.

# %%
#finding duplicated records in dataset
top.duplicated().sum()
# Out:
# 0

# %%
#renaming columns
top1 = top.rename(columns={"Length (Duration)": "Duration (sec)"})
top1.head()
# Out:
#                         Title             Artist            Top Genre  Year  \
# Index
# 1                     Sunrise        Norah Jones      adult standards  2004
# 2                 Black Night        Deep Purple           album rock  2000
# 3              Clint Eastwood           Gorillaz  alternative hip hop  2001
# 4               The Pretender       Foo Fighters    alternative metal  2007
# 5      Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
#
#        Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# Index
# 1                         157      30            53             14        11
# 2                         135      79            50             11        17
# 3                         168      69            66              9         7
# 4                         173      96            43              4         3
# 5                         106      82            58              5        10
#
#        Valence  Duration (sec)  Acousticness  Speechiness  Popularity
# Index
# 1           68             201            94            3          71
# 2           81             207            17            7          39
# 3           52             341             2           17          69
# 4           37             269             0            4          76
# 5           87             256             1            3          59

# %%
#so , because we find no missing values, next we are going to modificate our data.
#in this step, we will change type and values in column "Length(Duration)"
top1['Duration (sec)'].dtype
# Out:
# dtype('int64')

# %%
#replacing comma from numbers that make them string values by using replace() method
#and convert into integer by using to_numeric and apply methods
top1.replace(',','', regex=True, inplace=True)
top1['Duration (sec)']= top1['Duration (sec)'].apply(pd.to_numeric,errors='coerce')
top1['Duration (sec)'].dtype
# Out:
# dtype('int64')

# %%
#show the results
top1['Duration (sec)']
# Out:
# Index
# 1       201
# 2       207
# 3       341
# 4       269
# 5       256
#        ...
# 1990    128
# 1991    136
# 1992    162
# 1993    324
# 1994    148
# Name: Length (Duration), Length: 1994, dtype: int64

# %%
#describing the statistical part of column
top1['Duration (sec)'].describe()
# Out:
# count    1994.000000
# mean      262.443330
# std        93.604387
# min        93.000000
# 25%       212.000000
# 50%       245.000000
# 75%       289.000000
# max      1412.000000
# Name: Length (Duration), dtype: float64

# %%
#convert negative values in "Loudness " column to positive by using abs() function
top1['Loudness (dB)'] = top1['Loudness (dB)'].abs()
top1.head(5)
# Out:
#                         Title             Artist            Top Genre  Year  \
# Index
# 1                     Sunrise        Norah Jones      adult standards  2004
# 2                 Black Night        Deep Purple           album rock  2000
# 3              Clint Eastwood           Gorillaz  alternative hip hop  2001
# 4               The Pretender       Foo Fighters    alternative metal  2007
# 5      Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
#
#        Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# Index
# 1                         157      30            53             14        11
# 2                         135      79            50             11        17
# 3                         168      69            66              9         7
# 4                         173      96            43              4         3
# 5                         106      82            58              5        10
#
#        Valence  Length (Duration)  Acousticness  Speechiness  Popularity
# Index
# 1           68                201            94            3          71
# 2           81                207            17            7          39
# 3           52                341             2           17          69
# 4           37                269             0            4          76
# 5           87                256             1            3          59

# %%
#next, we'll define how many artists participate in our research
top1['Artist'].value_counts()
# Out:
# Queen                 37
# The Beatles           36
# Coldplay              27
# U2                    26
# The Rolling Stones    24
#                       ..
# The Band               1
# Ramones                1
# The Temper Trap        1
# Claudia De Breij       1
# Sam Smith              1
# Name: Artist, Length: 731, dtype: int64

# %%
#sorting songs from most to less popular
top1.sort_values(['Popularity'], ascending = False)
# Out:
#                                  Title                 Artist       Top Genre  \
# Index
# 794                       Dance Monkey            Tones and I  australian pop
# 788                           Memories               Maroon 5             pop
# 787                            bad guy          Billie Eilish      electropop
# 1642   All I Want for Christmas Is You           Mariah Carey       dance pop
# 727                            Shallow              Lady Gaga       dance pop
# ...                                ...                    ...             ...
# 606                    Het Dorp - Live          Wim Sonneveld   dutch cabaret
# 412                   Peter Gunn Theme  Emerson Lake & Palmer      album rock
# 625                Three Days In A Row                  Anouk     dutch indie
# 774                   Hou Vol Hou Vast                   BLØF       dutch pop
# 1794                         Sacrifice                  Anouk     dutch indie
#
#        Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# Index
# 794    2019                      98      59            82              6
# 788    2019                      91      32            76              7
# 787    2019                     135      43            70             11
# 1642   1994                     150      63            34              7
# 727    2018                      96      39            57              6
# ...     ...                     ...     ...           ...            ...
# 606    2015                     114      44            37             15
# 412    2010                     131      83            43              7
# 625    2015                     171      50            36              6
# 774    2018                      86      61            51              5
# 1794   1998                     136      17            54             13
#
#        Liveness  Valence  Duration (sec)  Acousticness  Speechiness  \
# Index
# 794          15       51             209            69            9
# 788           8       57             189            84            5
# 787          10       56             194            33           38
# 1642          7       35             241            16            4
# 727          23       32             216            37            3
# ...         ...      ...             ...           ...          ...
# 606          67       45             198            82            8
# 412          92       71             217             1            3
# 625          16       39             254             0            3
# 774           8       23             295             0            2
# 1794          9       24             238            74            5
#
#        Popularity
# Index
# 794           100
# 788            98
# 787            95
# 1642           95
# 727            88
# ...           ...
# 606            15
# 412            14
# 625            13
# 774            12
# 1794           11
#
# [1994 rows x 14 columns]

# %%
#here we define in which year each genre was the most popular
top1.groupby([ 'Top Genre']).aggregate({'Popularity' : 'max', 'Year' : 'max'})
# Out:
#                   Popularity  Year
# Top Genre
# acid jazz                 69  2006
# acoustic pop              82  2012
# adult standards           78  2017
# afropop                   59  2004
# alaska indie              41  2013
# ...                      ...   ...
# stomp and holler          64  2014
# streektaal                28  2017
# trance                    58  2004
# uk pop                    61  2005
# yacht rock                64  1984
#
# [149 rows x 2 columns]

# %%
top1
# Out:
#                         Title                    Artist            Top Genre  \
# Index
# 1                     Sunrise               Norah Jones      adult standards
# 2                 Black Night               Deep Purple           album rock
# 3              Clint Eastwood                  Gorillaz  alternative hip hop
# 4               The Pretender              Foo Fighters    alternative metal
# 5      Waitin' On A Sunny Day         Bruce Springsteen         classic rock
# ...                       ...                       ...                  ...
# 1990         Heartbreak Hotel             Elvis Presley      adult standards
# 1991                Hound Dog             Elvis Presley      adult standards
# 1992          Johnny B. Goode               Chuck Berry           blues rock
# 1993                Take Five  The Dave Brubeck Quartet                bebop
# 1994           Blueberry Hill               Fats Domino      adult standards
#
#        Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# Index
# 1      2004                     157      30            53             14
# 2      2000                     135      79            50             11
# 3      2001                     168      69            66              9
# 4      2007                     173      96            43              4
# 5      2002                     106      82            58              5
# ...     ...                     ...     ...           ...            ...
# 1990   1958                      94      21            70             12
# 1991   1958                     175      76            36              8
# 1992   1959                     168      80            53              9
# 1993   1959                     174      26            45             13
# 1994   1959                     133      50            49             10
#
#        Liveness  Valence  Duration (sec)  Acousticness  Speechiness  \
# Index
# 1            11       68             201            94            3
# 2            17       81             207            17            7
# 3             7       52             341             2           17
# 4             3       37             269             0            4
# 5            10       87             256             1            3
# ...         ...      ...             ...           ...          ...
# 1990         11       72             128            84            7
# 1991         76       95             136            73            6
# 1992         31       97             162            74            7
# 1993          7       60             324            54            4
# 1994         16       83             148            74            3
#
#        Popularity
# Index
# 1              71
# 2              39
# 3              69
# 4              76
# 5              59
# ...           ...
# 1990           63
# 1991           69
# 1992           74
# 1993           65
# 1994           56
#
# [1994 rows x 14 columns]

# %% [markdown]
# ## 5.Data visualisation

# %% [markdown]
# ### 5.1 Q1: Analyze the most known Artists in the world of all times and each decade
# * define artists with high marks of popularity in general terms and each decade
# * draw plots

# %%
top_artist = top[['Popularity','Artist']].sort_values(['Popularity'], ascending = False).head(5).plot()

# %%
top[['Title','Artist', 'Popularity', 'Year']].sort_values(['Year', 'Popularity'], ascending = False).tail(10)
# Out:
#                                                    Title  \
# Index
# 1828                                             At Last
# 1992                                     Johnny B. Goode
# 1993                                           Take Five
# 1994                                      Blueberry Hill
# 1987                                      Jailhouse Rock
# 1991                                           Hound Dog
# 1988   My Baby Just Cares for Me - 2013 Remastered Ve...
# 1989                                          Summertime
# 1990                                    Heartbreak Hotel
# 1986                                    Blue Suede Shoes
#
#                          Artist  Popularity  Year
# Index
# 1828                 Etta James          74  1960
# 1992                Chuck Berry          74  1959
# 1993   The Dave Brubeck Quartet          65  1959
# 1994                Fats Domino          56  1959
# 1987              Elvis Presley          73  1958
# 1991              Elvis Presley          69  1958
# 1988                Nina Simone          68  1958
# 1989            Louis Armstrong          66  1958
# 1990              Elvis Presley          63  1958
# 1986              Elvis Presley          62  1956

# %%
sns.lineplot( x = top1.Year, y = top1.Popularity)

# %% [markdown]
# here we can see that popularity of songs was high in 1960s. Most known
# artists: Elvis Presley, Etta James, Chuck Berry etc.

# %% [markdown]
# ### 5.2 Q2 : Analyze the most listened genres of all times and each decade
# * get genres with high marks of popularity each year and each decade
# * plot the given result

# %%
top1.groupby(['Top Genre']).aggregate({'Popularity' : 'max'})
# Out:
#                   Popularity
# Top Genre
# acid jazz                 69
# acoustic pop              82
# adult standards           78
# afropop                   59
# alaska indie              41
# ...                      ...
# stomp and holler          64
# streektaal                28
# trance                    58
# uk pop                    61
# yacht rock                64
#
# [149 rows x 1 columns]

# %%
sns.ax = sns.lmplot(x = 'Year', y = 'Popularity' ,hue = 'Top Genre',fit_reg=False,data = top1)
